# %% [markdown]
# # Loads the needed packages and reads the EMG data

# %%
import pandas as pd
import numpy as np
from read_emg import *
import seaborn as sns
from IPython.display import Image

plt.style.use('default')
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14
plt.rcParams['legend.fontsize'] = 12
plt.rcParams['legend.title_fontsize'] = 14
plt.rcParams['axes.labelsize'] = 16
pd.options.display.float_format = "{:,.3f}".format

# %%
### Reads the EMG data
df = pd.read_pickle('DataCollection.pkl')
df['Trial_num'] = df['Trial_num'].astype(int)

# %% [markdown]
# # Function that calculates the cross-correlation (Similarity)

# %%
Image(url= "Similarity.png", width=600, height=600)
# Out:
# <img src="Similarity.png" width="600" height="600"/>

# %%
### Calculating the similarity using the channel means
def cross_correlation_vector(A, B):
    A_vector = []
    B_vector = []
    for channel in range(0, 8):
        A_temp = A[:, channel] 
        A_channel_mean = A_temp.mean()
        A_vector.append(A_channel_mean)
        
        B_temp = B[:, channel]
        B_channel_mean = B_temp.mean()
        B_vector.append(B_channel_mean)
        
    A_vector = np.array(A_vector)
    B_vector = np.array(B_vector)
    C = np.multiply(A_vector, B_vector).sum() / (np.sqrt((A_vector**2).sum() * (B_vector**2).sum()))

    return C

# %% [markdown]
# # Function that flip the channels around ( 1 2 3 4 to 4 3 2 1)

# %%
def flipping_sensor(df_unflipped):
    A = df_unflipped.iloc[:, :8]
    A = A.loc[:, ::-1].values
    
    df_flipped = df_unflipped.copy()
    df_flipped.iloc[:, :8] = A
    
    return df_flipped

# %% [markdown]
# # Function that calculates the similarity between non-shifted and shifted channels

# %%
def CC_to_shift(df, subject_reference, subject_to_rotate, calibration_gesture, session_reference, session_to_rotate, plot = False):
    shift_list = []
    
    if plot == True:
        fig, ax = plt.subplots(3, 4, figsize = (21, 12))
        R = 0 
        Col = 0
        
    print(f'Current Subject: {subject_to_rotate}')
    df_A = df[(df['ID'] == subject_reference) & 
              (df['Gesture'] == calibration_gesture) & 
              (df['Trial_num'] == 3) & 
              (df['session'] == session_reference)].iloc[:, :8]

    A_value = df_A.iloc[100:, :8].rolling(20).mean().dropna().values

    shift_range = range(0, 8)

    max_CC = 0
    final_status = False
    final_shift = 0
    for flipped in [False, True]:
        if flipped == False:    
            df_B = df[(df['ID'] == subject_to_rotate) & 
                      (df['Gesture'] == calibration_gesture) & 
                      (df['Trial_num'] <= 3) & 
                      (df['session'] == session_to_rotate)].iloc[:, :8]
        else:
            print('Flipping the sensor\n')
            df_B = flipping_sensor(df[(df['ID'] == subject_to_rotate)  & 
                                      (df['Gesture'] == calibration_gesture) & 
                                      (df['Trial_num'] <= 3) & 
                                      (df['session'] == session_to_rotate)]).iloc[:, :8]
        

        B = df_B.iloc[100:, :8].rolling(20).mean().dropna()     
         
        CC_list = []
        for shift in shift_range:
            print(f'Shift: {shift}')

            B_value = pd.concat((B,B), axis = 1).iloc[:,  0 + shift:8 + shift].values

            C = cross_correlation_vector(A_value, B_value)
            print(f'CC: {C:.4f}\n')
            CC_list.append(C)
        try:
            shift_idx = np.where(CC_list == np.max(CC_list))[0][0]
            shift_list.append(shift_idx)

            if np.max(CC_list) > max_CC:
                max_CC = np.max(CC_list)
                final_status = flipped
                final_shift = shift_idx
                
        except Exception as e:
            print(e)

    print(f'\nFlipping needed? {final_status}\n')

    return final_status, shift_list

# %%
def shift_to_rotation(df, shift, subject_reference, subject_to_rotate, session_reference, session_to_rotate, flipped):
    df_train = df[(df['ID'] == subject_reference) & (df['session'] == session_reference) & (df['Trial_num'] <=3)]
        
    df_test = df[(df['ID'] == subject_to_rotate) & (df['session'] == session_to_rotate) & (df['Trial_num'] <=3)]
    

    df_test_temp = df_test.iloc[:, :8].copy()
    
    if flipped == True:
        df_test_temp = flipping_sensor(df_test.iloc[:, :8])
        df_test = flipping_sensor(df_test)
        
    df_test_calibrated = pd.concat((pd.concat((df_test_temp, df_test_temp), axis = 1).iloc[:,  0 + shift:8 + shift], df_test.iloc[:, 8:]), axis = 1)
    df_test_calibrated = pd.DataFrame(df_test_calibrated.values, columns = df_test.columns)
            
    return df_train, df_test, df_test_calibrated

# %% [markdown]
# # Calculates the similarity of gestures between 2 sessions in the same subject

# %%
subject_list = list(df['ID'].unique())
gesture_list = ['2', '4', '5', '6', '7', '8', '9']
label_list = ['Cylinder Grasp', 'Wrist Extension', 'Fist', 'Finger mass extension', 'Opposition', 'Wrist / Finger extension', 'Lateral Pinch']
int_to_label = dict(zip(gesture_list, label_list))
stats = list()

for subject in ['0001', '1001', '1002', '1003', '1004', '1005', '1006', '1007', '1008', '1111', '1234', '9999'][:]:
    print('\n###############################')
    print(f'Current subject: {subject}')
    print('###############################\n')

        
    flipped, shift_list = CC_to_shift(df, 
                        subject_reference = subject, 
                        subject_to_rotate = subject, 
                        calibration_gesture = '8', 
                        session_reference = 'S1', 
                        session_to_rotate = 'S2')
    flipped = False
    
    if flipped == False:
        shift = shift_list[0]
    else:
        shift = shift_list[1]    
        
    
    df_reference, df_original, df_calibrated = shift_to_rotation(df, shift, 
                                                                 subject_reference = subject, 
                                                                 subject_to_rotate = subject,
                                                                 session_reference = 'S1', 
                                                                 session_to_rotate = 'S2', 
                                                                 flipped = flipped)
    print('Gesutre: Cross-correlation')
    for gesture in gesture_list[:]:
        df_reference_to_plot = df_reference[(df_reference['Gesture'] == gesture)]
        df_rotated_to_plot = df_calibrated[(df_calibrated['Gesture'] == gesture)]
        
        A = df_reference_to_plot.iloc[:, :8].values
        B = df_rotated_to_plot.iloc[:, :8].values

        C= cross_correlation_vector(A, B)
        print(f'{int_to_label[gesture]}: {C:.2f}')
        stats.append({'ID':subject,
                      'shift': shift,
                      'Gesture': int_to_label[gesture],
                      'CC': C})
# Out:
# ###############################
# Current subject: 0001
# ###############################
#
# Current Subject: 0001
# Shift: 0
# CC: 0.9717
#
# Shift: 1
# CC: 0.7386
#
# Shift: 2
# CC: 0.5124
#
# Shift: 3
# CC: 0.4231
#
# Shift: 4
# CC: 0.4457
#
# Shift: 5
# CC: 0.4936
#
# Shift: 6
# CC: 0.6393
#
# Shift: 7
# CC: 0.9050
#
# Flipping the sensor
#
# Shift: 0
# CC: 0.8091
#
# Shift: 1
# CC: 0.9691
#
# Shift: 2
# CC: 0.8278
#
# Shift: 3
# CC: 0.6491
#
# Shift: 4
# CC: 0.5565
#
# Shift: 5
# CC: 0.4279
#
# Shift: 6
# CC: 0.3669
#
# Shift: 7
# CC: 0.5230
#
#
# Flipping needed? False
#
# Gesutre: Cross-correlation
# Cylinder Grasp: 0.95
# Wrist Extension: 0.99
# Fist: 0.95
# Finger mass extension: 0.98
# Opposition: 0.96
# Wrist / Finger extension: 0.97
# Lateral Pinch: 0.97
#
# ###############################
# Current subject: 1001
# ###############################
#
# Current Subject: 1001
# Shift: 0
# CC: 0.9893
#
# Shift: 1
# CC: 0.8728
#
# Shift: 2
# CC: 0.7161
#
# Shift: 3
# CC: 0.5958
#
# Shift: 4
# CC: 0.5747
#
# Shift: 5
# CC: 0.6698
#
# Shift: 6
# CC: 0.8345
#
# Shift: 7
# CC: 0.9622
#
# Flipping the sensor
#
# Shift: 0
# CC: 0.8383
#
# Shift: 1
# CC: 0.9766
#
# Shift: 2
# CC: 0.9768
#
# Shift: 3
# CC: 0.8682
#
# Shift: 4
# CC: 0.7075
#
# Shift: 5
# CC: 0.5898
#
# Shift: 6
# CC: 0.5780
#
# Shift: 7
# CC: 0.6799
#
#
# Flipping needed? False
#
# Gesutre: Cross-correlation
# Cylinder Grasp: 0.98
# Wrist Extension: 0.98
# Fist: 0.99
# Finger mass extension: 0.99
# Opposition: 0.98
# Wrist / Finger extension: 0.99
# Lateral Pinch: 0.96
#
# ###############################
# Current subject: 1002
# ###############################
#
# Current Subject: 1002
# Shift: 0
# CC: 0.9986
#
# Shift: 1
# CC: 0.8869
#
# Shift: 2
# CC: 0.7001
#
# Shift: 3
# CC: 0.5645
#
# Shift: 4
# CC: 0.5214
#
# Shift: 5
# CC: 0.5932
#
# Shift: 6
# CC: 0.7470
#
# Shift: 7
# CC: 0.9216
#
# Flipping the sensor
#
# Shift: 0
# CC: 0.6534
#
# Shift: 1
# CC: 0.8344
#
# Shift: 2
# CC: 0.9848
#
# Shift: 3
# CC: 0.9595
#
# Shift: 4
# CC: 0.7988
#
# Shift: 5
# CC: 0.6295
#
# Shift: 6
# CC: 0.5291
#
# Shift: 7
# CC: 0.5436
#
#
# Flipping needed? False
#
# Gesutre: Cross-correlation
# Cylinder Grasp: 1.00
# Wrist Extension: 1.00
# Fist: 0.99
# Finger mass extension: 1.00
# Opposition: 0.99
# Wrist / Finger extension: 1.00
# Lateral Pinch: 0.99
#
# ###############################
# Current subject: 1003
# ###############################
#
# Current Subject: 1003
# Shift: 0
# CC: 0.9936
#
# Shift: 1
# CC: 0.8778
#
# Shift: 2
# CC: 0.6333
#
# Shift: 3
# CC: 0.4454
#
# Shift: 4
# CC: 0.3745
#
# Shift: 5
# CC: 0.4075
#
# Shift: 6
# CC: 0.5715
#
# Shift: 7
# CC: 0.7995
#
# Flipping the sensor
#
# Shift: 0
# CC: 0.8286
#
# Shift: 1
# CC: 0.9796
#
# Shift: 2
# CC: 0.8742
#
# Shift: 3
# CC: 0.6058
#
# Shift: 4
# CC: 0.4174
#
# Shift: 5
# CC: 0.3888
#
# Shift: 6
# CC: 0.4099
#
# Shift: 7
# CC: 0.5987
#
#
# Flipping needed? False
#
# Gesutre: Cross-correlation
# Cylinder Grasp: 0.98
# Wrist Extension: 0.99
# Fist: 0.99
# Finger mass extension: 1.00
# Opposition: 1.00
# Wrist / Finger extension: 0.99
# Lateral Pinch: 0.99
#
# ###############################
# Current subject: 1004
# ###############################
#
# Current Subject: 1004
# Shift: 0
# CC: 0.8718
#
# Shift: 1
# CC: 0.9980
#
# Shift: 2
# CC: 0.8238
#
# Shift: 3
# CC: 0.5508
#
# Shift: 4
# CC: 0.4044
#
# Shift: 5
# CC: 0.3798
#
# Shift: 6
# CC: 0.4303
#
# Shift: 7
# CC: 0.6039
#
# Flipping the sensor
#
# Shift: 0
# CC: 0.9928
#
# Shift: 1
# CC: 0.8918
#
# Shift: 2
# CC: 0.6227
#
# Shift: 3
# CC: 0.4284
#
# Shift: 4
# CC: 0.3803
#
# Shift: 5
# CC: 0.4069
#
# Shift: 6
# CC: 0.5365
#
# Shift: 7
# CC: 0.8032
#
#
# Flipping needed? False
#
# Gesutre: Cross-correlation
# Cylinder Grasp: 0.96
# Wrist Extension: 1.00
# Fist: 0.99
# Finger mass extension: 1.00
# Opposition: 0.99
# Wrist / Finger extension: 1.00
# Lateral Pinch: 0.99
#
# ###############################
# Current subject: 1005
# ###############################
#
# Current Subject: 1005
# Shift: 0
# CC: 0.9872
#
# Shift: 1
# CC: 0.9590
#
# Shift: 2
# CC: 0.8203
#
# Shift: 3
# CC: 0.6851
#
# Shift: 4
# CC: 0.6232
#
# Shift: 5
# CC: 0.6515
#
# Shift: 6
# CC: 0.7560
#
# Shift: 7
# CC: 0.8910
#
# Flipping the sensor
#
# Shift: 0
# CC: 0.7335
#
# Shift: 1
# CC: 0.8748
#
# Shift: 2
# CC: 0.9841
#
# Shift: 3
# CC: 0.9676
#
# Shift: 4
# CC: 0.8392
#
# Shift: 5
# CC: 0.7057
#
# Shift: 6
# CC: 0.6297
#
# Shift: 7
# CC: 0.6386
#
#
# Flipping needed? False
#
# Gesutre: Cross-correlation
# Cylinder Grasp: 0.97
# Wrist Extension: 0.99
# Fist: 0.98
# Finger mass extension: 0.99
# Opposition: 0.97
# Wrist / Finger extension: 0.99
# Lateral Pinch: 0.97
#
# ###############################
# Current subject: 1006
# ###############################
#
# Current Subject: 1006
# Shift: 0
# CC: 0.9921
#
# Shift: 1
# CC: 0.9116
#
# Shift: 2
# CC: 0.7063
#
# Shift: 3
# CC: 0.5375
#
# Shift: 4
# CC: 0.4548
#
# Shift: 5
# CC: 0.4800
#
# Shift: 6
# CC: 0.6252
#
# Shift: 7
# CC: 0.8491
#
# Flipping the sensor
#
# Shift: 0
# CC: 0.9822
#
# Shift: 1
# CC: 0.9354
#
# Shift: 2
# CC: 0.7478
#
# Shift: 3
# CC: 0.5720
#
# Shift: 4
# CC: 0.4644
#
# Shift: 5
# CC: 0.4596
#
# Shift: 6
# CC: 0.5838
#
# Shift: 7
# CC: 0.8114
#
#
# Flipping needed? False
#
# Gesutre: Cross-correlation
# Cylinder Grasp: 1.00
# Wrist Extension: 0.99
# Fist: 1.00
# Finger mass extension: 1.00
# Opposition: 0.96
# Wrist / Finger extension: 1.00
# Lateral Pinch: 1.00
#
# ###############################
# Current subject: 1007
# ###############################
#
# Current Subject: 1007
# Shift: 0
# CC: 0.8473
#
# Shift: 1
# CC: 0.6814
#
# Shift: 2
# CC: 0.5861
#
# Shift: 3
# CC: 0.5775
#
# Shift: 4
# CC: 0.6320
#
# Shift: 5
# CC: 0.7610
#
# Shift: 6
# CC: 0.9453
#
# Shift: 7
# CC: 0.9667
#
# Flipping the sensor
#
# Shift: 0
# CC: 0.7118
#
# Shift: 1
# CC: 0.9131
#
# Shift: 2
# CC: 0.9638
#
# Shift: 3
# CC: 0.8758
#
# Shift: 4
# CC: 0.7590
#
# Shift: 5
# CC: 0.6448
#
# Shift: 6
# CC: 0.5519
#
# Shift: 7
# CC: 0.5769
#
#
# Flipping needed? False
#
# Gesutre: Cross-correlation
# Cylinder Grasp: 0.96
# Wrist Extension: 0.99
# Fist: 0.97
# Finger mass extension: 0.93
# Opposition: 0.99
# Wrist / Finger extension: 0.97
# Lateral Pinch: 0.94
#
# ###############################
# Current subject: 1008
# ###############################
#
# Current Subject: 1008
# Shift: 0
# CC: 0.9904
#
# Shift: 1
# CC: 0.9200
#
# Shift: 2
# CC: 0.7877
#
# Shift: 3
# CC: 0.6771
#
# Shift: 4
# CC: 0.6406
#
# Shift: 5
# CC: 0.6629
#
# Shift: 6
# CC: 0.7395
#
# Shift: 7
# CC: 0.8767
#
# Flipping the sensor
#
# Shift: 0
# CC: 0.9292
#
# Shift: 1
# CC: 0.9882
#
# Shift: 2
# CC: 0.8673
#
# Shift: 3
# CC: 0.7429
#
# Shift: 4
# CC: 0.6623
#
# Shift: 5
# CC: 0.6396
#
# Shift: 6
# CC: 0.6779
#
# Shift: 7
# CC: 0.7876
#
#
# Flipping needed? False
#
# Gesutre: Cross-correlation
# Cylinder Grasp: 0.93
# Wrist Extension: 0.97
# Fist: 0.91
# Finger mass extension: 0.93
# Opposition: 0.95
# Wrist / Finger extension: 0.99
# Lateral Pinch: 0.79
#
# ###############################
# Current subject: 1111
# ###############################
#
# Current Subject: 1111
# Shift: 0
# CC: 0.9638
#
# Shift: 1
# CC: 0.8661
#
# Shift: 2
# CC: 0.6799
#
# Shift: 3
# CC: 0.5966
#
# Shift: 4
# CC: 0.5872
#
# Shift: 5
# CC: 0.6094
#
# Shift: 6
# CC: 0.6740
#
# Shift: 7
# CC: 0.8047
#
# Flipping the sensor
#
# Shift: 0
# CC: 0.8485
#
# Shift: 1
# CC: 0.9638
#
# Shift: 2
# CC: 0.8253
#
# Shift: 3
# CC: 0.6536
#
# Shift: 4
# CC: 0.6114
#
# Shift: 5
# CC: 0.5917
#
# Shift: 6
# CC: 0.5916
#
# Shift: 7
# CC: 0.6957
#
#
# Flipping needed? True
#
# Gesutre: Cross-correlation
# Cylinder Grasp: 0.95
# Wrist Extension: 0.96
# Fist: 0.95
# Finger mass extension: 0.99
# Opposition: 0.83
# Wrist / Finger extension: 0.95
# Lateral Pinch: 0.96
#
# ###############################
# Current subject: 1234
# ###############################
#
# Current Subject: 1234
# Shift: 0
# CC: 0.7501
#
# Shift: 1
# CC: 0.6553
#
# Shift: 2
# CC: 0.6668
#
# Shift: 3
# CC: 0.6865
#
# Shift: 4
# CC: 0.7384
#
# Shift: 5
# CC: 0.8782
#
# Shift: 6
# CC: 0.9941
#
# Shift: 7
# CC: 0.9173
#
# Flipping the sensor
#
# Shift: 0
# CC: 0.9424
#
# Shift: 1
# CC: 0.8205
#
# Shift: 2
# CC: 0.7325
#
# Shift: 3
# CC: 0.6915
#
# Shift: 4
# CC: 0.6344
#
# Shift: 5
# CC: 0.6615
#
# Shift: 6
# CC: 0.8281
#
# Shift: 7
# CC: 0.9760
#
#
# Flipping needed? False
#
# Gesutre: Cross-correlation
# Cylinder Grasp: 0.99
# Wrist Extension: 1.00
# Fist: 1.00
# Finger mass extension: 0.98
# Opposition: 0.99
# Wrist / Finger extension: 1.00
# Lateral Pinch: 0.98
#
# ###############################
# Current subject: 9999
# ###############################
#
# Current Subject: 9999
# Shift: 0
# CC: 0.9787
#
# Shift: 1
# CC: 0.8534
#
# Shift: 2
# CC: 0.5318
#
# Shift: 3
# CC: 0.3791
#
# Shift: 4
# CC: 0.2906
#
# Shift: 5
# CC: 0.2726
#
# Shift: 6
# CC: 0.3813
#
# Shift: 7
# CC: 0.6753
#
# Flipping the sensor
#
# Shift: 0
# CC: 0.2901
#
# Shift: 1
# CC: 0.5444
#
# Shift: 2
# CC: 0.9143
#
# Shift: 3
# CC: 0.9264
#
# Shift: 4
# CC: 0.6383
#
# Shift: 5
# CC: 0.4639
#
# Shift: 6
# CC: 0.3375
#
# Shift: 7
# CC: 0.2475
#
#
# Flipping needed? False
#
# Gesutre: Cross-correlation
# Cylinder Grasp: 0.99
# Wrist Extension: 0.90
# Fist: 0.98
# Finger mass extension: 0.98
# Opposition: 0.98
# Wrist / Finger extension: 0.98
# Lateral Pinch: 0.98

# %% [markdown]
# # Printing the similarity of gestures between 2 sessions in the same subject

# %%
stats = pd.DataFrame(stats)
stats.groupby('Gesture')['CC'].mean()
# Out:
# Gesture
# Cylinder Grasp             0.970
# Finger mass extension      0.980
# Fist                       0.975
# Lateral Pinch              0.960
# Opposition                 0.965
# Wrist / Finger extension   0.987
# Wrist Extension            0.980
# Name: CC, dtype: float64
