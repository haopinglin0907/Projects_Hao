# %% [markdown]
# # Import packages

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split
import lightgbm as lgb

import warnings
warnings.filterwarnings("ignore") # ignore warnings

# %% [markdown]
# # Load Data

# %%
# load and preview data
df = pd.read_csv('Breast_cancer_data.csv')
df.head()
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    diagnosis
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
# view summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mean_radius      569 non-null    float64
#  1   mean_texture     569 non-null    float64
#  2   mean_perimeter   569 non-null    float64
#  3   mean_area        569 non-null    float64
#  4   mean_smoothness  569 non-null    float64
#  5   diagnosis        569 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 26.8 KB

# %%
# print positive/negative labels
df['diagnosis'].value_counts()
# Out:
# 1    357
# 0    212
# Name: diagnosis, dtype: int64

# %%
X = df[['mean_radius','mean_texture','mean_perimeter','mean_area','mean_smoothness']]
y = df['diagnosis']

# %% [markdown]
# # Split train-test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %% [markdown]
# ## Building LightGBM model

# %%
# build the lightgbm model
model = lgb.LGBMClassifier()
lgb_params = {
    'boosting_type': ['gbdt'],
    'objective': ['binary'],
    'num_leaves': [5, 30],
    'learning_rate': [0.01],
    'reg_alpha':[0, 0.1, 0.3],
    'reg_lambda':[0, 0.1, 0.3]
}

grid_cv = GridSearchCV(model, lgb_params, cv = 3, verbose = 1)
grid_cv.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# GridSearchCV(cv=3, estimator=LGBMClassifier(),
#              param_grid={'boosting_type': ['gbdt'], 'learning_rate': [0.01],
#                          'num_leaves': [5, 30], 'objective': ['binary'],
#                          'reg_alpha': [0, 0.1, 0.3],
#                          'reg_lambda': [0, 0.1, 0.3]},
#              verbose=1)

# %%
print(grid_cv.best_params_)
# Out:
# {'boosting_type': 'gbdt', 'learning_rate': 0.01, 'num_leaves': 5, 'objective': 'binary', 'reg_alpha': 0.3, 'reg_lambda': 0}

# %%
# define categorical variables
# build the lightgbm model
best_params = grid_cv.best_params_
lgb_train = lgb.Dataset(X_train, y_train)
lgb_test = lgb.Dataset(X_test, y_test)
bst = lgb.train(best_params, lgb_train, 1000, valid_sets=lgb_test, early_stopping_rounds=20)
# Out:
# [LightGBM] [Info] Number of positive: 249, number of negative: 149
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 665
# [LightGBM] [Info] Number of data points in the train set: 398, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.625628 -> initscore=0.513507
# [LightGBM] [Info] Start training from score 0.513507
# [1]	valid_0's binary_logloss: 0.651027
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's binary_logloss: 0.64403
# [3]	valid_0's binary_logloss: 0.637189
# [4]	valid_0's binary_logloss: 0.630498
# [5]	valid_0's binary_logloss: 0.623953
# [6]	valid_0's binary_logloss: 0.61755
# [7]	valid_0's binary_logloss: 0.611282
# [8]	valid_0's binary_logloss: 0.605147
# [9]	valid_0's binary_logloss: 0.599141
# [10]	valid_0's binary_logloss: 0.593259
# [11]	valid_0's binary_logloss: 0.587497
# [12]	valid_0's binary_logloss: 0.581853
# [13]	valid_0's binary_logloss: 0.576323
# [14]	valid_0's binary_logloss: 0.570904
# [15]	valid_0's binary_logloss: 0.565592
# [16]	valid_0's binary_logloss: 0.560385
# [17]	valid_0's binary_logloss: 0.555279
# [18]	valid_0's binary_logloss: 0.550553
# [19]	valid_0's binary_logloss: 0.545633
# [20]	valid_0's binary_logloss: 0.540808
# [21]	valid_0's binary_logloss: 0.536074
# [22]	valid_0's binary_logloss: 0.53143
# [23]	valid_0's binary_logloss: 0.526873
# [24]	valid_0's binary_logloss: 0.522401
# [25]	valid_0's binary_logloss: 0.517985
# [26]	valid_0's binary_logloss: 0.513748
# [27]	valid_0's binary_logloss: 0.509126
# [28]	valid_0's binary_logloss: 0.504585
# [29]	valid_0's binary_logloss: 0.500363
# [30]	valid_0's binary_logloss: 0.496417
# [31]	valid_0's binary_logloss: 0.492098
# [32]	valid_0's binary_logloss: 0.488083
# [33]	valid_0's binary_logloss: 0.484131
# [34]	valid_0's binary_logloss: 0.480247
# [35]	valid_0's binary_logloss: 0.47643
# [36]	valid_0's binary_logloss: 0.472855
# [37]	valid_0's binary_logloss: 0.469153
# [38]	valid_0's binary_logloss: 0.465416
# [39]	valid_0's binary_logloss: 0.461835
# [40]	valid_0's binary_logloss: 0.458085
# [41]	valid_0's binary_logloss: 0.454595
# [42]	valid_0's binary_logloss: 0.451163
# [43]	valid_0's binary_logloss: 0.44779
# [44]	valid_0's binary_logloss: 0.444472
# [45]	valid_0's binary_logloss: 0.441211
# [46]	valid_0's binary_logloss: 0.438003
# [47]	valid_0's binary_logloss: 0.43473
# [48]	valid_0's binary_logloss: 0.431616
# [49]	valid_0's binary_logloss: 0.428558
# [50]	valid_0's binary_logloss: 0.425621
# [51]	valid_0's binary_logloss: 0.422456
# [52]	valid_0's binary_logloss: 0.419536
# [53]	valid_0's binary_logloss: 0.416733
# [54]	valid_0's binary_logloss: 0.413699
# [55]	valid_0's binary_logloss: 0.410909
# [56]	valid_0's binary_logloss: 0.408027
# [57]	valid_0's binary_logloss: 0.405388
# [58]	valid_0's binary_logloss: 0.402723
# [59]	valid_0's binary_logloss: 0.399882
# [60]	valid_0's binary_logloss: 0.396874
# [61]	valid_0's binary_logloss: 0.394426
# [62]	valid_0's binary_logloss: 0.391498
# [63]	valid_0's binary_logloss: 0.388617
# [64]	valid_0's binary_logloss: 0.386169
# [65]	valid_0's binary_logloss: 0.383364
# [66]	valid_0's binary_logloss: 0.381081
# [67]	valid_0's binary_logloss: 0.378349
# [68]	valid_0's binary_logloss: 0.37566
# [69]	valid_0's binary_logloss: 0.373371
# [70]	valid_0's binary_logloss: 0.370831
# [71]	valid_0's binary_logloss: 0.368247
# [72]	valid_0's binary_logloss: 0.365703
# [73]	valid_0's binary_logloss: 0.363626
# [74]	valid_0's binary_logloss: 0.361147
# [75]	valid_0's binary_logloss: 0.358724
# [76]	valid_0's binary_logloss: 0.35634
# [77]	valid_0's binary_logloss: 0.354418
# [78]	valid_0's binary_logloss: 0.352376
# [79]	valid_0's binary_logloss: 0.350077
# [80]	valid_0's binary_logloss: 0.347814
# [81]	valid_0's binary_logloss: 0.345998
# [82]	valid_0's binary_logloss: 0.343794
# [83]	valid_0's binary_logloss: 0.34198
# [84]	valid_0's binary_logloss: 0.339833
# [85]	valid_0's binary_logloss: 0.337719
# [86]	valid_0's binary_logloss: 0.335639
# [87]	valid_0's binary_logloss: 0.333837
# [88]	valid_0's binary_logloss: 0.33221
# [89]	valid_0's binary_logloss: 0.33021
# [90]	valid_0's binary_logloss: 0.328594
# [91]	valid_0's binary_logloss: 0.327039
# [92]	valid_0's binary_logloss: 0.325468
# [93]	valid_0's binary_logloss: 0.323561
# [94]	valid_0's binary_logloss: 0.322076
# [95]	valid_0's binary_logloss: 0.320524
# [96]	valid_0's binary_logloss: 0.318688
# [97]	valid_0's binary_logloss: 0.31727
# [98]	valid_0's binary_logloss: 0.315876
# [99]	valid_0's binary_logloss: 0.314114
# [100]	valid_0's binary_logloss: 0.312657
# [101]	valid_0's binary_logloss: 0.311379
# [102]	valid_0's binary_logloss: 0.30968
# [103]	valid_0's binary_logloss: 0.308441
# [104]	valid_0's binary_logloss: 0.307224
# [105]	valid_0's binary_logloss: 0.305653
# [106]	valid_0's binary_logloss: 0.304032
# [107]	valid_0's binary_logloss: 0.302868
# [108]	valid_0's binary_logloss: 0.30129
# [109]	valid_0's binary_logloss: 0.300162
# [110]	valid_0's binary_logloss: 0.299019
# [111]	valid_0's binary_logloss: 0.297743
# [112]	valid_0's binary_logloss: 0.29624
# [113]	valid_0's binary_logloss: 0.29515
# [114]	valid_0's binary_logloss: 0.293688
# [115]	valid_0's binary_logloss: 0.292357
# [116]	valid_0's binary_logloss: 0.291318
# [117]	valid_0's binary_logloss: 0.290299
# [118]	valid_0's binary_logloss: 0.288979
# [119]	valid_0's binary_logloss: 0.287824
# [120]	valid_0's binary_logloss: 0.286852
# [121]	valid_0's binary_logloss: 0.285502
# [122]	valid_0's binary_logloss: 0.284542
# [123]	valid_0's binary_logloss: 0.283228
# [124]	valid_0's binary_logloss: 0.282143
# [125]	valid_0's binary_logloss: 0.281204
# [126]	valid_0's binary_logloss: 0.279981
# [127]	valid_0's binary_logloss: 0.278815
# [128]	valid_0's binary_logloss: 0.27794
# [129]	valid_0's binary_logloss: 0.276757
# [130]	valid_0's binary_logloss: 0.275911
# [131]	valid_0's binary_logloss: 0.274971
# [132]	valid_0's binary_logloss: 0.273868
# [133]	valid_0's binary_logloss: 0.272757
# [134]	valid_0's binary_logloss: 0.271639
# [135]	valid_0's binary_logloss: 0.270718
# [136]	valid_0's binary_logloss: 0.269947
# [137]	valid_0's binary_logloss: 0.269118
# [138]	valid_0's binary_logloss: 0.268046
# [139]	valid_0's binary_logloss: 0.267024
# [140]	valid_0's binary_logloss: 0.266229
# [141]	valid_0's binary_logloss: 0.265216
# [142]	valid_0's binary_logloss: 0.264371
# [143]	valid_0's binary_logloss: 0.263611
# [144]	valid_0's binary_logloss: 0.262605
# [145]	valid_0's binary_logloss: 0.261544
# [146]	valid_0's binary_logloss: 0.260814
# [147]	valid_0's binary_logloss: 0.260099
# [148]	valid_0's binary_logloss: 0.259136
# [149]	valid_0's binary_logloss: 0.258342
# [150]	valid_0's binary_logloss: 0.257657
# [151]	valid_0's binary_logloss: 0.256725
# [152]	valid_0's binary_logloss: 0.255727
# [153]	valid_0's binary_logloss: 0.254916
# [154]	valid_0's binary_logloss: 0.254168
# [155]	valid_0's binary_logloss: 0.253367
# [156]	valid_0's binary_logloss: 0.252742
# [157]	valid_0's binary_logloss: 0.251917
# [158]	valid_0's binary_logloss: 0.251158
# [159]	valid_0's binary_logloss: 0.250417
# [160]	valid_0's binary_logloss: 0.249668
# [161]	valid_0's binary_logloss: 0.249089
# [162]	valid_0's binary_logloss: 0.24837
# [163]	valid_0's binary_logloss: 0.247716
# [164]	valid_0's binary_logloss: 0.247025
# [165]	valid_0's binary_logloss: 0.246095
# [166]	valid_0's binary_logloss: 0.245351
# [167]	valid_0's binary_logloss: 0.244677
# [168]	valid_0's binary_logloss: 0.244117
# [169]	valid_0's binary_logloss: 0.243403
# [170]	valid_0's binary_logloss: 0.242762
# [171]	valid_0's binary_logloss: 0.242021
# [172]	valid_0's binary_logloss: 0.241388
# [173]	valid_0's binary_logloss: 0.24087
# [174]	valid_0's binary_logloss: 0.24026
# [175]	valid_0's binary_logloss: 0.239599
# [176]	valid_0's binary_logloss: 0.239007
# [177]	valid_0's binary_logloss: 0.23831
# [178]	valid_0's binary_logloss: 0.237725
# [179]	valid_0's binary_logloss: 0.237251
# [180]	valid_0's binary_logloss: 0.236632
# [181]	valid_0's binary_logloss: 0.236076
# [182]	valid_0's binary_logloss: 0.235416
# [183]	valid_0's binary_logloss: 0.234841
# [184]	valid_0's binary_logloss: 0.234404
# [185]	valid_0's binary_logloss: 0.233879
# [186]	valid_0's binary_logloss: 0.233177
# [187]	valid_0's binary_logloss: 0.232551
# [188]	valid_0's binary_logloss: 0.232034
# [189]	valid_0's binary_logloss: 0.231629
# [190]	valid_0's binary_logloss: 0.231102
# [191]	valid_0's binary_logloss: 0.23071
# [192]	valid_0's binary_logloss: 0.230209
# [193]	valid_0's binary_logloss: 0.229704
# [194]	valid_0's binary_logloss: 0.22912
# [195]	valid_0's binary_logloss: 0.228651
# [196]	valid_0's binary_logloss: 0.22829
# [197]	valid_0's binary_logloss: 0.227809
# [198]	valid_0's binary_logloss: 0.227179
# [199]	valid_0's binary_logloss: 0.226627
# [200]	valid_0's binary_logloss: 0.226186
# [201]	valid_0's binary_logloss: 0.225729
# [202]	valid_0's binary_logloss: 0.225402
# [203]	valid_0's binary_logloss: 0.224979
# [204]	valid_0's binary_logloss: 0.22456
# [205]	valid_0's binary_logloss: 0.224248
# [206]	valid_0's binary_logloss: 0.223806
# [207]	valid_0's binary_logloss: 0.223217
# [208]	valid_0's binary_logloss: 0.222712
# [209]	valid_0's binary_logloss: 0.222321
# [210]	valid_0's binary_logloss: 0.221915
# [211]	valid_0's binary_logloss: 0.221635
# [212]	valid_0's binary_logloss: 0.221273
# [213]	valid_0's binary_logloss: 0.220792
# [214]	valid_0's binary_logloss: 0.22032
# [215]	valid_0's binary_logloss: 0.21996
# [216]	valid_0's binary_logloss: 0.219704
# [217]	valid_0's binary_logloss: 0.219303
# [218]	valid_0's binary_logloss: 0.218769
# [219]	valid_0's binary_logloss: 0.21841
# [220]	valid_0's binary_logloss: 0.217962
# [221]	valid_0's binary_logloss: 0.217603
# [222]	valid_0's binary_logloss: 0.217342
# [223]	valid_0's binary_logloss: 0.217019
# [224]	valid_0's binary_logloss: 0.216714
# [225]	valid_0's binary_logloss: 0.216287
# [226]	valid_0's binary_logloss: 0.215953
# [227]	valid_0's binary_logloss: 0.215599
# [228]	valid_0's binary_logloss: 0.215395
# [229]	valid_0's binary_logloss: 0.215075
# [230]	valid_0's binary_logloss: 0.214575
# [231]	valid_0's binary_logloss: 0.21424
# [232]	valid_0's binary_logloss: 0.213841
# [233]	valid_0's binary_logloss: 0.213539
# [234]	valid_0's binary_logloss: 0.213327
# [235]	valid_0's binary_logloss: 0.213056
# [236]	valid_0's binary_logloss: 0.212767
# [237]	valid_0's binary_logloss: 0.212458
# [238]	valid_0's binary_logloss: 0.212032
# [239]	valid_0's binary_logloss: 0.211786
# [240]	valid_0's binary_logloss: 0.211525
# [241]	valid_0's binary_logloss: 0.211288
# [242]	valid_0's binary_logloss: 0.210713
# [243]	valid_0's binary_logloss: 0.210463
# [244]	valid_0's binary_logloss: 0.210205
# [245]	valid_0's binary_logloss: 0.209927
# [246]	valid_0's binary_logloss: 0.20969
# [247]	valid_0's binary_logloss: 0.209483
# [248]	valid_0's binary_logloss: 0.208933
# [249]	valid_0's binary_logloss: 0.208704
# [250]	valid_0's binary_logloss: 0.208541
# [251]	valid_0's binary_logloss: 0.208308
# [252]	valid_0's binary_logloss: 0.208081
# [253]	valid_0's binary_logloss: 0.207778
# [254]	valid_0's binary_logloss: 0.207318
# [255]	valid_0's binary_logloss: 0.207109
# [256]	valid_0's binary_logloss: 0.206961
# [257]	valid_0's binary_logloss: 0.206675
# [258]	valid_0's binary_logloss: 0.206159
# [259]	valid_0's binary_logloss: 0.205882
# [260]	valid_0's binary_logloss: 0.205703
# [261]	valid_0's binary_logloss: 0.205528
# [262]	valid_0's binary_logloss: 0.205261
# [263]	valid_0's binary_logloss: 0.204764
# [264]	valid_0's binary_logloss: 0.204599
# [265]	valid_0's binary_logloss: 0.204343
# [266]	valid_0's binary_logloss: 0.204088
# [267]	valid_0's binary_logloss: 0.203841
# [268]	valid_0's binary_logloss: 0.20336
# [269]	valid_0's binary_logloss: 0.203114
# [270]	valid_0's binary_logloss: 0.202877
# [271]	valid_0's binary_logloss: 0.202394
# [272]	valid_0's binary_logloss: 0.20229
# [273]	valid_0's binary_logloss: 0.202064
# [274]	valid_0's binary_logloss: 0.201604
# [275]	valid_0's binary_logloss: 0.201437
# [276]	valid_0's binary_logloss: 0.201209
# [277]	valid_0's binary_logloss: 0.201003
# [278]	valid_0's binary_logloss: 0.20076
# [279]	valid_0's binary_logloss: 0.20052
# [280]	valid_0's binary_logloss: 0.200064
# [281]	valid_0's binary_logloss: 0.199866
# [282]	valid_0's binary_logloss: 0.199636
# [283]	valid_0's binary_logloss: 0.199411
# [284]	valid_0's binary_logloss: 0.19927
# [285]	valid_0's binary_logloss: 0.199085
# [286]	valid_0's binary_logloss: 0.198647
# [287]	valid_0's binary_logloss: 0.19839
# [288]	valid_0's binary_logloss: 0.198182
# [289]	valid_0's binary_logloss: 0.198056
# [290]	valid_0's binary_logloss: 0.197791
# [291]	valid_0's binary_logloss: 0.197547
# [292]	valid_0's binary_logloss: 0.197126
# [293]	valid_0's binary_logloss: 0.196887
# [294]	valid_0's binary_logloss: 0.196775
# [295]	valid_0's binary_logloss: 0.196522
# [296]	valid_0's binary_logloss: 0.196292
# [297]	valid_0's binary_logloss: 0.196188
# [298]	valid_0's binary_logloss: 0.195964
# [299]	valid_0's binary_logloss: 0.19564
# [300]	valid_0's binary_logloss: 0.195505
# [301]	valid_0's binary_logloss: 0.195265
# [302]	valid_0's binary_logloss: 0.19505
# [303]	valid_0's binary_logloss: 0.194735
# [304]	valid_0's binary_logloss: 0.194608
# [305]	valid_0's binary_logloss: 0.194378
# [306]	valid_0's binary_logloss: 0.194183
# [307]	valid_0's binary_logloss: 0.193991
# [308]	valid_0's binary_logloss: 0.193612
# [309]	valid_0's binary_logloss: 0.193391
# [310]	valid_0's binary_logloss: 0.193169
# [311]	valid_0's binary_logloss: 0.192987
# [312]	valid_0's binary_logloss: 0.192691
# [313]	valid_0's binary_logloss: 0.192478
# [314]	valid_0's binary_logloss: 0.192266
# [315]	valid_0's binary_logloss: 0.192123
# [316]	valid_0's binary_logloss: 0.191912
# [317]	valid_0's binary_logloss: 0.191742
# [318]	valid_0's binary_logloss: 0.191541
# [319]	valid_0's binary_logloss: 0.191361
# [320]	valid_0's binary_logloss: 0.191006
# [321]	valid_0's binary_logloss: 0.190721
# [322]	valid_0's binary_logloss: 0.190522
# [323]	valid_0's binary_logloss: 0.190326
# [324]	valid_0's binary_logloss: 0.19013
# [325]	valid_0's binary_logloss: 0.189938
# [326]	valid_0's binary_logloss: 0.189887
# [327]	valid_0's binary_logloss: 0.189629
# [328]	valid_0's binary_logloss: 0.189359
# [329]	valid_0's binary_logloss: 0.189172
# [330]	valid_0's binary_logloss: 0.188883
# [331]	valid_0's binary_logloss: 0.18862
# [332]	valid_0's binary_logloss: 0.188443
# [333]	valid_0's binary_logloss: 0.188146
# [334]	valid_0's binary_logloss: 0.188003
# [335]	valid_0's binary_logloss: 0.187962
# [336]	valid_0's binary_logloss: 0.18771
# [337]	valid_0's binary_logloss: 0.187471
# [338]	valid_0's binary_logloss: 0.187299
# [339]	valid_0's binary_logloss: 0.187027
# [340]	valid_0's binary_logloss: 0.186744
# [341]	valid_0's binary_logloss: 0.186646
# [342]	valid_0's binary_logloss: 0.186583
# [343]	valid_0's binary_logloss: 0.186453
# [344]	valid_0's binary_logloss: 0.186289
# [345]	valid_0's binary_logloss: 0.186261
# [346]	valid_0's binary_logloss: 0.186026
# [347]	valid_0's binary_logloss: 0.185794
# [348]	valid_0's binary_logloss: 0.185524
# [349]	valid_0's binary_logloss: 0.185297
# [350]	valid_0's binary_logloss: 0.185033
# [351]	valid_0's binary_logloss: 0.184781
# [352]	valid_0's binary_logloss: 0.184664
# [353]	valid_0's binary_logloss: 0.184512
# [354]	valid_0's binary_logloss: 0.184327
# [355]	valid_0's binary_logloss: 0.184249
# [356]	valid_0's binary_logloss: 0.184233
# [357]	valid_0's binary_logloss: 0.184019
# [358]	valid_0's binary_logloss: 0.183912
# [359]	valid_0's binary_logloss: 0.1839
# [360]	valid_0's binary_logloss: 0.183651
# [361]	valid_0's binary_logloss: 0.183444
# [362]	valid_0's binary_logloss: 0.183317
# [363]	valid_0's binary_logloss: 0.183075
# [364]	valid_0's binary_logloss: 0.182974
# [365]	valid_0's binary_logloss: 0.182969
# [366]	valid_0's binary_logloss: 0.182831
# [367]	valid_0's binary_logloss: 0.182627
# [368]	valid_0's binary_logloss: 0.182475
# [369]	valid_0's binary_logloss: 0.182414
# [370]	valid_0's binary_logloss: 0.18222
# [371]	valid_0's binary_logloss: 0.181969
# [372]	valid_0's binary_logloss: 0.181778
# [373]	valid_0's binary_logloss: 0.181532
# [374]	valid_0's binary_logloss: 0.181389
# [375]	valid_0's binary_logloss: 0.18126
# [376]	valid_0's binary_logloss: 0.18102
# [377]	valid_0's binary_logloss: 0.180971
# [378]	valid_0's binary_logloss: 0.180812
# [379]	valid_0's binary_logloss: 0.180661
# [380]	valid_0's binary_logloss: 0.180611
# [381]	valid_0's binary_logloss: 0.180621
# [382]	valid_0's binary_logloss: 0.180539
# [383]	valid_0's binary_logloss: 0.180522
# [384]	valid_0's binary_logloss: 0.180401
# [385]	valid_0's binary_logloss: 0.180227
# [386]	valid_0's binary_logloss: 0.18
# [387]	valid_0's binary_logloss: 0.179871
# [388]	valid_0's binary_logloss: 0.179701
# [389]	valid_0's binary_logloss: 0.179619
# [390]	valid_0's binary_logloss: 0.179399
# [391]	valid_0's binary_logloss: 0.179256
# [392]	valid_0's binary_logloss: 0.179143
# [393]	valid_0's binary_logloss: 0.178928
# [394]	valid_0's binary_logloss: 0.178849
# [395]	valid_0's binary_logloss: 0.178815
# [396]	valid_0's binary_logloss: 0.178739
# [397]	valid_0's binary_logloss: 0.178761
# [398]	valid_0's binary_logloss: 0.178784
# [399]	valid_0's binary_logloss: 0.178676
# [400]	valid_0's binary_logloss: 0.178506
# [401]	valid_0's binary_logloss: 0.178373
# [402]	valid_0's binary_logloss: 0.178268
# [403]	valid_0's binary_logloss: 0.178065
# [404]	valid_0's binary_logloss: 0.177994
# [405]	valid_0's binary_logloss: 0.177866
# [406]	valid_0's binary_logloss: 0.177909
# [407]	valid_0's binary_logloss: 0.177841
# [408]	valid_0's binary_logloss: 0.177741
# [409]	valid_0's binary_logloss: 0.177545
# [410]	valid_0's binary_logloss: 0.177479
# [411]	valid_0's binary_logloss: 0.177302
# [412]	valid_0's binary_logloss: 0.177246
# [413]	valid_0's binary_logloss: 0.177254
# [414]	valid_0's binary_logloss: 0.177134
# [415]	valid_0's binary_logloss: 0.176946
# [416]	valid_0's binary_logloss: 0.176829
# [417]	valid_0's binary_logloss: 0.176735
# [418]	valid_0's binary_logloss: 0.176552
# [419]	valid_0's binary_logloss: 0.176493
# [420]	valid_0's binary_logloss: 0.176435
# [421]	valid_0's binary_logloss: 0.176488
# [422]	valid_0's binary_logloss: 0.176323
# [423]	valid_0's binary_logloss: 0.176276
# [424]	valid_0's binary_logloss: 0.176167
# [425]	valid_0's binary_logloss: 0.176113
# [426]	valid_0's binary_logloss: 0.176069
# [427]	valid_0's binary_logloss: 0.17606
# [428]	valid_0's binary_logloss: 0.1761
# [429]	valid_0's binary_logloss: 0.176014
# [430]	valid_0's binary_logloss: 0.176034
# [431]	valid_0's binary_logloss: 0.175876
# [432]	valid_0's binary_logloss: 0.175827
# [433]	valid_0's binary_logloss: 0.17587
# [434]	valid_0's binary_logloss: 0.175833
# [435]	valid_0's binary_logloss: 0.175743
# [436]	valid_0's binary_logloss: 0.175708
# [437]	valid_0's binary_logloss: 0.175733
# [438]	valid_0's binary_logloss: 0.175621
# [439]	valid_0's binary_logloss: 0.175456
# [440]	valid_0's binary_logloss: 0.175412
# [441]	valid_0's binary_logloss: 0.175303
# [442]	valid_0's binary_logloss: 0.175272
# [443]	valid_0's binary_logloss: 0.175301
# [444]	valid_0's binary_logloss: 0.17514
# [445]	valid_0's binary_logloss: 0.174995
# [446]	valid_0's binary_logloss: 0.174955
# [447]	valid_0's binary_logloss: 0.174928
# [448]	valid_0's binary_logloss: 0.174785
# [449]	valid_0's binary_logloss: 0.174639
# [450]	valid_0's binary_logloss: 0.174614
# [451]	valid_0's binary_logloss: 0.174619
# [452]	valid_0's binary_logloss: 0.174476
# [453]	valid_0's binary_logloss: 0.174454
# [454]	valid_0's binary_logloss: 0.174315
# [455]	valid_0's binary_logloss: 0.174176
# [456]	valid_0's binary_logloss: 0.174044
# [457]	valid_0's binary_logloss: 0.17399
# [458]	valid_0's binary_logloss: 0.173892
# [459]	valid_0's binary_logloss: 0.173862
# [460]	valid_0's binary_logloss: 0.173711
# [461]	valid_0's binary_logloss: 0.173659
# [462]	valid_0's binary_logloss: 0.173564
# [463]	valid_0's binary_logloss: 0.173416
# [464]	valid_0's binary_logloss: 0.1734
# [465]	valid_0's binary_logloss: 0.173268
# [466]	valid_0's binary_logloss: 0.173242
# [467]	valid_0's binary_logloss: 0.173122
# [468]	valid_0's binary_logloss: 0.17303
# [469]	valid_0's binary_logloss: 0.172936
# [470]	valid_0's binary_logloss: 0.17282
# [471]	valid_0's binary_logloss: 0.172806
# [472]	valid_0's binary_logloss: 0.172668
# [473]	valid_0's binary_logloss: 0.172655
# [474]	valid_0's binary_logloss: 0.172608
# [475]	valid_0's binary_logloss: 0.172521
# [476]	valid_0's binary_logloss: 0.172384
# [477]	valid_0's binary_logloss: 0.172339
# [478]	valid_0's binary_logloss: 0.172254
# [479]	valid_0's binary_logloss: 0.17221
# [480]	valid_0's binary_logloss: 0.172093
# [481]	valid_0's binary_logloss: 0.172083
# [482]	valid_0's binary_logloss: 0.172144
# [483]	valid_0's binary_logloss: 0.171967
# [484]	valid_0's binary_logloss: 0.171884
# [485]	valid_0's binary_logloss: 0.171843
# [486]	valid_0's binary_logloss: 0.171836
# [487]	valid_0's binary_logloss: 0.171662
# [488]	valid_0's binary_logloss: 0.171622
# [489]	valid_0's binary_logloss: 0.171649
# [490]	valid_0's binary_logloss: 0.171625
# [491]	valid_0's binary_logloss: 0.171475
# [492]	valid_0's binary_logloss: 0.171379
# [493]	valid_0's binary_logloss: 0.17121
# [494]	valid_0's binary_logloss: 0.17116
# [495]	valid_0's binary_logloss: 0.171189
# [496]	valid_0's binary_logloss: 0.171096
# [497]	valid_0's binary_logloss: 0.170929
# [498]	valid_0's binary_logloss: 0.170894
# [499]	valid_0's binary_logloss: 0.170822
# [500]	valid_0's binary_logloss: 0.170852
# [501]	valid_0's binary_logloss: 0.170804
# [502]	valid_0's binary_logloss: 0.170853
# [503]	valid_0's binary_logloss: 0.170782
# [504]	valid_0's binary_logloss: 0.170906
# [505]	valid_0's binary_logloss: 0.170913
# [506]	valid_0's binary_logloss: 0.170881
# [507]	valid_0's binary_logloss: 0.170997
# [508]	valid_0's binary_logloss: 0.170922
# [509]	valid_0's binary_logloss: 0.170852
# [510]	valid_0's binary_logloss: 0.170817
# [511]	valid_0's binary_logloss: 0.170772
# [512]	valid_0's binary_logloss: 0.170804
# [513]	valid_0's binary_logloss: 0.170735
# [514]	valid_0's binary_logloss: 0.170666
# [515]	valid_0's binary_logloss: 0.170598
# [516]	valid_0's binary_logloss: 0.170554
# [517]	valid_0's binary_logloss: 0.17068
# [518]	valid_0's binary_logloss: 0.170613
# [519]	valid_0's binary_logloss: 0.17057
# [520]	valid_0's binary_logloss: 0.170543
# [521]	valid_0's binary_logloss: 0.170453
# [522]	valid_0's binary_logloss: 0.170427
# [523]	valid_0's binary_logloss: 0.170357
# [524]	valid_0's binary_logloss: 0.170391
# [525]	valid_0's binary_logloss: 0.170511
# [526]	valid_0's binary_logloss: 0.170447
# [527]	valid_0's binary_logloss: 0.170406
# [528]	valid_0's binary_logloss: 0.170441
# [529]	valid_0's binary_logloss: 0.170379
# [530]	valid_0's binary_logloss: 0.170356
# [531]	valid_0's binary_logloss: 0.170287
# [532]	valid_0's binary_logloss: 0.170219
# [533]	valid_0's binary_logloss: 0.170179
# [534]	valid_0's binary_logloss: 0.170158
# [535]	valid_0's binary_logloss: 0.170193
# [536]	valid_0's binary_logloss: 0.170081
# [537]	valid_0's binary_logloss: 0.170015
# [538]	valid_0's binary_logloss: 0.170138
# [539]	valid_0's binary_logloss: 0.170119
# [540]	valid_0's binary_logloss: 0.170053
# [541]	valid_0's binary_logloss: 0.170089
# [542]	valid_0's binary_logloss: 0.170213
# [543]	valid_0's binary_logloss: 0.170162
# [544]	valid_0's binary_logloss: 0.170078
# [545]	valid_0's binary_logloss: 0.17004
# [546]	valid_0's binary_logloss: 0.170023
# [547]	valid_0's binary_logloss: 0.169959
# [548]	valid_0's binary_logloss: 0.169997
# [549]	valid_0's binary_logloss: 0.169971
# [550]	valid_0's binary_logloss: 0.169908
# [551]	valid_0's binary_logloss: 0.169946
# [552]	valid_0's binary_logloss: 0.170071
# [553]	valid_0's binary_logloss: 0.170008
# [554]	valid_0's binary_logloss: 0.169983
# [555]	valid_0's binary_logloss: 0.169918
# [556]	valid_0's binary_logloss: 0.169869
# [557]	valid_0's binary_logloss: 0.169995
# [558]	valid_0's binary_logloss: 0.170034
# [559]	valid_0's binary_logloss: 0.169974
# [560]	valid_0's binary_logloss: 0.169987
# [561]	valid_0's binary_logloss: 0.169925
# [562]	valid_0's binary_logloss: 0.169913
# [563]	valid_0's binary_logloss: 0.169839
# [564]	valid_0's binary_logloss: 0.169817
# [565]	valid_0's binary_logloss: 0.169856
# [566]	valid_0's binary_logloss: 0.169983
# [567]	valid_0's binary_logloss: 0.169924
# [568]	valid_0's binary_logloss: 0.169864
# [569]	valid_0's binary_logloss: 0.169837
# [570]	valid_0's binary_logloss: 0.169776
# [571]	valid_0's binary_logloss: 0.169816
# [572]	valid_0's binary_logloss: 0.169832
# [573]	valid_0's binary_logloss: 0.169787
# [574]	valid_0's binary_logloss: 0.169915
# [575]	valid_0's binary_logloss: 0.169956
# [576]	valid_0's binary_logloss: 0.169899
# [577]	valid_0's binary_logloss: 0.16984
# [578]	valid_0's binary_logloss: 0.169816
# [579]	valid_0's binary_logloss: 0.169833
# [580]	valid_0's binary_logloss: 0.169812
# [581]	valid_0's binary_logloss: 0.169754
# [582]	valid_0's binary_logloss: 0.169796
# [583]	valid_0's binary_logloss: 0.169925
# [584]	valid_0's binary_logloss: 0.169881
# [585]	valid_0's binary_logloss: 0.169824
# [586]	valid_0's binary_logloss: 0.169756
# [587]	valid_0's binary_logloss: 0.169699
# [588]	valid_0's binary_logloss: 0.169741
# [589]	valid_0's binary_logloss: 0.169722
# [590]	valid_0's binary_logloss: 0.169665
# [591]	valid_0's binary_logloss: 0.169735
# [592]	valid_0's binary_logloss: 0.169681
# [593]	valid_0's binary_logloss: 0.169663
# [594]	valid_0's binary_logloss: 0.169706
# [595]	valid_0's binary_logloss: 0.169652
# [596]	valid_0's binary_logloss: 0.169723
# [597]	valid_0's binary_logloss: 0.169708
# [598]	valid_0's binary_logloss: 0.169816
# [599]	valid_0's binary_logloss: 0.169763
# [600]	valid_0's binary_logloss: 0.169699
# [601]	valid_0's binary_logloss: 0.169808
# [602]	valid_0's binary_logloss: 0.169787
# [603]	valid_0's binary_logloss: 0.169734
# [604]	valid_0's binary_logloss: 0.169777
# [605]	valid_0's binary_logloss: 0.169849
# [606]	valid_0's binary_logloss: 0.169837
# [607]	valid_0's binary_logloss: 0.169785
# [608]	valid_0's binary_logloss: 0.169771
# [609]	valid_0's binary_logloss: 0.169757
# [610]	valid_0's binary_logloss: 0.169677
# [611]	valid_0's binary_logloss: 0.169721
# [612]	valid_0's binary_logloss: 0.169743
# [613]	valid_0's binary_logloss: 0.169692
# [614]	valid_0's binary_logloss: 0.169614
# [615]	valid_0's binary_logloss: 0.169626
# [616]	valid_0's binary_logloss: 0.169616
# [617]	valid_0's binary_logloss: 0.169727
# [618]	valid_0's binary_logloss: 0.169678
# [619]	valid_0's binary_logloss: 0.169602
# [620]	valid_0's binary_logloss: 0.169594
# [621]	valid_0's binary_logloss: 0.169705
# [622]	valid_0's binary_logloss: 0.169658
# [623]	valid_0's binary_logloss: 0.169566
# [624]	valid_0's binary_logloss: 0.16958
# [625]	valid_0's binary_logloss: 0.169573
# [626]	valid_0's binary_logloss: 0.169684
# [627]	valid_0's binary_logloss: 0.169666
# [628]	valid_0's binary_logloss: 0.169619
# [629]	valid_0's binary_logloss: 0.169731
# [630]	valid_0's binary_logloss: 0.169714
# [631]	valid_0's binary_logloss: 0.169654
# [632]	valid_0's binary_logloss: 0.1697
# [633]	valid_0's binary_logloss: 0.169714
# [634]	valid_0's binary_logloss: 0.169787
# [635]	valid_0's binary_logloss: 0.169741
# [636]	valid_0's binary_logloss: 0.169737
# [637]	valid_0's binary_logloss: 0.169849
# [638]	valid_0's binary_logloss: 0.169858
# [639]	valid_0's binary_logloss: 0.169813
# [640]	valid_0's binary_logloss: 0.169756
# [641]	valid_0's binary_logloss: 0.169771
# [642]	valid_0's binary_logloss: 0.169769
# [643]	valid_0's binary_logloss: 0.169882
# Early stopping, best iteration is:
# [623]	valid_0's binary_logloss: 0.169566

# %%
plt.figure(figsize=(12,6))
lgb.plot_importance(bst, max_num_features=30)
plt.title("Feature importances")
# Out:
# Text(0.5, 1.0, 'Feature importances')

# %%
y_pred = bst.predict(X_test)
y_pred = np.where(y_pred > 0.5, 1, 0)

y_pred_train = bst.predict(X_train)
y_pred_train = np.where(y_pred_train > 0.5, 1, 0)

# %%
# print the scores on training and test set
print('Training set score: {:.4f}'.format(accuracy_score(y_train, y_pred_train)))
print('Test set score: {:.4f}'.format(accuracy_score(y_test, y_pred)))
# Out:
# Training set score: 0.9749
# Test set score: 0.9240

# %%
# Print the Confusion Matrix and slice it into four pieces
cm = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = cm.ravel()
print('Confusion matrix\n\n', cm)
print('\nTrue Positives(TP) = ', tp)
print('\nTrue Negatives(TN) = ', tn)
print('\nFalse Positives(FP) = ', fp)
print('\nFalse Negatives(FN) = ', fn)
# Out:
# Confusion matrix
#
#  [[ 55   8]
#  [  5 103]]
#
# True Positives(TP) =  103
#
# True Negatives(TN) =  55
#
# False Positives(FP) =  8
#
# False Negatives(FN) =  5

# %%
# calculate the fpr and tpr for all thresholds of the classification
probs = bst.predict(X_test)
fpr, tpr, threshold = metrics.roc_curve(y_test, probs)
roc_auc = metrics.auc(fpr, tpr)

# method I: plt
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([-0.03, 1])
plt.ylim([0, 1.05])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
