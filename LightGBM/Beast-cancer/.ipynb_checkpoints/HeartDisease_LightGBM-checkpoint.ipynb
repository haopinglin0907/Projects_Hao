# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization

import warnings
warnings.filterwarnings("ignore") # ignore warnings

# %%
# load and preview data
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# view summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# print positive/negative labels
df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
X = df.iloc[:, :-1]
y = df['target']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.model_selection import GridSearchCV

# %%
model = lgb.LGBMClassifier()
lgb_params = {
    'boosting_type': ['gbdt'],
    'objective': ['binary'],
    'num_leaves': [10, 15, 20],
    'learning_rate': [0.01, 0.03, 0.06, 0.1],
    'max_depth': [2, 3, 4],
    'reg_lambda': [0, 1, 3],
    'reg_alpha':[0, 1, 3],
    'feature_fraction':[0.6, 0.7]
}

# %%
grid_cv = GridSearchCV(model, lgb_params, cv = 3, verbose = 10)
grid_cv.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 648 candidates, totalling 1944 fits
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=0, score=0.845, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=0, score=0.817, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=0, score=0.843, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=1, score=0.859, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=1, score=0.817, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=1, score=0.829, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s remaining:    0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=3, score=0.817, total=   0.1s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=3, score=0.831, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=3, score=0.829, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=0, score=0.845, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=0, score=0.803, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=0
# [LightGBM] [Warning]
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.2s remaining:    0.0s
# feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=0, score=0.843, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=1, score=0.817, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=1, score=0.803, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=2, num_leaves
total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=3, score=0.829, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=0, score=0.831, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=0, score=0.817, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=0, score=0.829, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=1, score=0.817, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=1, score=0.817, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=1, score=0.829, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=3, score=0.803, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=3, score=0.803, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=1, reg_lambda=3, score=0.829, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=0, score=0.803, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=0, score=0.817, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=0, score=0.829, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=1, score=0.789, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=1, score=0.817, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=1, score=0.814, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=3, score=0.789, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=3, score=0.803, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=10, objective=binary, reg_alpha=3, reg_lambda=3, score=0.814, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=15, objective=binary, reg_alpha=0, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [CV]  boosting_type=gbdt, feature_fraction=0.6, learning_rate=0.01, max_depth=3, num_leaves=15, objective=binary, reg_alpha=0, reg_lambda=0, score=0.817, total=   0.0s
# ...
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=15, objective=binary, reg_alpha=3, reg_lambda=0, score=0.871, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=15, objective=binary, reg_alpha=3, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=15, objective=binary, reg_alpha=3, reg_lambda=1, score=0.803, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=15, objective=binary, reg_alpha=3, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=15, objective=binary, reg_alpha=3, reg_lambda=1, score=0.817, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=15, objective=binary, reg_alpha=3, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=15, objective=binary, reg_alpha=3, reg_lambda=1, score=0.871, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=15, objective=binary, reg_alpha=3, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=15, objective=binary, reg_alpha=3, reg_lambda=3, score=0.803, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=15, objective=binary, reg_alpha=3, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=15, objective=binary, reg_alpha=3, reg_lambda=3, score=0.817, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=15, objective=binary, reg_alpha=3, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=15, objective=binary, reg_alpha=3, reg_lambda=3, score=0.871, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=0, score=0.732, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=0, score=0.789, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=0, score=0.857, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=1, score=0.789, total=   0.1s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=1, score=0.817, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=1, score=0.843, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=3, score=0.775, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=3, score=0.817, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=0, reg_lambda=3, score=0.857, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=0, score=0.789, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=0, score=0.817, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=0, score=0.871, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=1, score=0.803, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=1, score=0.831, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=1, score=0.871, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=3, score=0.746, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=3, score=0.803, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=1, reg_lambda=3, score=0.886, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=0, score=0.803, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=0, score=0.817, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=0
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=0, score=0.871, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=1, score=0.803, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=1, score=0.817, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=1
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=1, score=0.871, total=   0.1s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=3, score=0.803, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=3, score=0.817, total=   0.0s
# [CV] boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=3
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [CV]  boosting_type=gbdt, feature_fraction=0.7, learning_rate=0.1, max_depth=4, num_leaves=20, objective=binary, reg_alpha=3, reg_lambda=3, score=0.871, total=   0.0s
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [Parallel(n_jobs=1)]: Done 1944 out of 1944 | elapsed:  1.2min finished
# GridSearchCV(cv=3, error_score=nan,
#              estimator=LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                       colsample_bytree=1.0,
#                                       importance_type='split',
#                                       learning_rate=0.1, max_depth=-1,
#                                       min_child_samples=20,
#                                       min_child_weight=0.001,
#                                       min_split_gain=0.0, n_estimators=100,
#                                       n_jobs=-1, num_leaves=31, objective=None,
#                                       random_state=None, reg_alpha=0.0,
#                                       reg_lambda=0.0, silent=True,
#                                       subsample=1.0, subsample_for_bin=200000,
#                                       subsample_freq=0),
#              iid='deprecated', n_jobs=None,
#              param_grid={'boosting_type': ['gbdt'],
#                          'feature_fraction': [0.6, 0.7],
#                          'learning_rate': [0.01, 0.03, 0.06, 0.1],
#                          'max_depth': [2, 3, 4], 'num_leaves': [10, 15, 20],
#                          'objective': ['binary'], 'reg_alpha': [0, 1, 3],
#                          'reg_lambda': [0, 1, 3]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=10)

# %%
print(grid_cv.best_params_)
# Out:
# {'boosting_type': 'gbdt', 'feature_fraction': 0.6, 'learning_rate': 0.06, 'max_depth': 3, 'num_leaves': 10, 'objective': 'binary', 'reg_alpha': 0, 'reg_lambda': 1}

# %%
# define categorical variables
categorical_features = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']
# build the lightgbm model
import lightgbm as lgb
best_params = grid_cv.best_params_
lgb_train = lgb.Dataset(X_train, y_train, categorical_feature = categorical_features)
lgb_test = lgb.Dataset(X_test, y_test, categorical_feature = categorical_features)
bst = lgb.train(best_params, lgb_train, 1000, valid_sets=lgb_test, early_stopping_rounds=5)
# Out:
# [LightGBM] [Info] Number of positive: 118, number of negative: 94
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000125 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 231
# [LightGBM] [Info] Number of data points in the train set: 212, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.556604 -> initscore=0.227390
# [LightGBM] [Info] Start training from score 0.227390
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's binary_logloss: 0.677512
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's binary_logloss: 0.661213
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's binary_logloss: 0.64751
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's binary_logloss: 0.632314
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's binary_logloss: 0.620625
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's binary_logloss: 0.613325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's binary_logloss: 0.605232
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's binary_logloss: 0.596095
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's binary_logloss: 0.588765
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's binary_logloss: 0.578691
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's binary_logloss: 0.569759
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's binary_logloss: 0.563679
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's binary_logloss: 0.557875
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's binary_logloss: 0.551562
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's binary_logloss: 0.542976
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's binary_logloss: 0.539549
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's binary_logloss: 0.531707
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's binary_logloss: 0.529012
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's binary_logloss: 0.526759
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's binary_logloss: 0.522501
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's binary_logloss: 0.521956
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's binary_logloss: 0.518206
# [23]	valid_0's binary_logloss: 0.515648
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's binary_logloss: 0.512126
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's binary_logloss: 0.508376
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's binary_logloss: 0.504501
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's binary_logloss: 0.501557
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's binary_logloss: 0.499152
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's binary_logloss: 0.496727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's binary_logloss: 0.49614
# [31]	valid_0's binary_logloss: 0.49608
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's binary_logloss: 0.494856
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's binary_logloss: 0.490958
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's binary_logloss: 0.487657
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's binary_logloss: 0.486631
# [36]	valid_0's binary_logloss: 0.485289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid_0's binary_logloss: 0.483644
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's binary_logloss: 0.479237
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's binary_logloss: 0.477509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's binary_logloss: 0.475921
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's binary_logloss: 0.474367
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's binary_logloss: 0.472693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's binary_logloss: 0.471485
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's binary_logloss: 0.470069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's binary_logloss: 0.468954
# [46]	valid_0's binary_logloss: 0.46714
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's binary_logloss: 0.465914
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's binary_logloss: 0.464277
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's binary_logloss: 0.46201
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's binary_logloss: 0.461468
# [51]	valid_0's binary_logloss: 0.458062
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's binary_logloss: 0.458261
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's binary_logloss: 0.456302
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	valid_0's binary_logloss: 0.455945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [55]	valid_0's binary_logloss: 0.453805
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [56]	valid_0's binary_logloss: 0.452837
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [57]	valid_0's binary_logloss: 0.453086
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [58]	valid_0's binary_logloss: 0.451965
# [59]	valid_0's binary_logloss: 0.448872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	valid_0's binary_logloss: 0.44815
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [61]	valid_0's binary_logloss: 0.446979
# [62]	valid_0's binary_logloss: 0.447658
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [63]	valid_0's binary_logloss: 0.447273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [64]	valid_0's binary_logloss: 0.446506
# [65]	valid_0's binary_logloss: 0.443947
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [66]	valid_0's binary_logloss: 0.443449
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [67]	valid_0's binary_logloss: 0.443017
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	valid_0's binary_logloss: 0.441844
# [69]	valid_0's binary_logloss: 0.439245
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	valid_0's binary_logloss: 0.438191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	valid_0's binary_logloss: 0.437161
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [72]	valid_0's binary_logloss: 0.437341
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	valid_0's binary_logloss: 0.437408
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [74]	valid_0's binary_logloss: 0.435741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [75]	valid_0's binary_logloss: 0.436267
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [76]	valid_0's binary_logloss: 0.436093
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [77]	valid_0's binary_logloss: 0.435873
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [78]	valid_0's binary_logloss: 0.434518
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [79]	valid_0's binary_logloss: 0.434968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	valid_0's binary_logloss: 0.434145
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [81]	valid_0's binary_logloss: 0.434423
# [82]	valid_0's binary_logloss: 0.432818
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [83]	valid_0's binary_logloss: 0.432571
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [84]	valid_0's binary_logloss: 0.431642
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [85]	valid_0's binary_logloss: 0.431533
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [86]	valid_0's binary_logloss: 0.432043
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [87]	valid_0's binary_logloss: 0.43275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [88]	valid_0's binary_logloss: 0.432534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [89]	valid_0's binary_logloss: 0.432853
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	valid_0's binary_logloss: 0.432969
# Early stopping, best iteration is:
# [85]	valid_0's binary_logloss: 0.431533

# %%
plt.figure(figsize=(12,6))
lgb.plot_importance(bst, max_num_features=30)
plt.title("Feature importances")
plt.show()

# %%
y_pred = bst.predict(X_test)
y_pred = np.where(y_pred > 0.5, 1, 0)

y_pred_train = bst.predict(X_train)
y_pred_train = np.where(y_pred_train > 0.5, 1, 0)

# %%
# view accuracy
from sklearn.metrics import accuracy_score
# print the scores on training and test set
print('Training set score: {:.4f}'.format(accuracy_score(y_train, y_pred_train)))
print('Test set score: {:.4f}'.format(accuracy_score(y_test, y_pred)))
# Out:
# Training set score: 0.9104
# Test set score: 0.8132

# %%
import sklearn.metrics as metrics
# calculate the fpr and tpr for all thresholds of the classification
probs = bst.predict(X_test)
fpr, tpr, threshold = metrics.roc_curve(y_test, probs)
roc_auc = metrics.auc(fpr, tpr)

# method I: plt
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([-0.03, 1])
plt.ylim([0, 1.03])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
