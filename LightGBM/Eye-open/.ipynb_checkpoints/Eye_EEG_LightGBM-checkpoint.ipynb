# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization

import warnings
warnings.filterwarnings("ignore") # ignore warnings

# %%
# load and preview data
df = pd.read_csv('stroke.csv')
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
bmi_fe = df.loc[df['gender'] == 'Female', 'bmi'].mean()
bmi_ma = df.loc[df['gender'] == 'Male', 'bmi'].mean()
bmi_oth = df.loc[df['gender'] == 'Other', 'bmi'].mean()

# %%
df.loc[df['gender'] == 'Female', 'bmi'] = df.loc[df['gender'] == 'Female', 'bmi'].fillna(bmi_fe)
df.loc[df['gender'] == 'Male', 'bmi'] = df.loc[df['gender'] == 'Male', 'bmi'].fillna(bmi_ma)
df.loc[df['gender'] == 'Other', 'bmi'] = df.loc[df['gender'] == 'Other', 'bmi'].fillna(bmi_oth)

# %%
# view summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
# id                   5110 non-null int64
# gender               5110 non-null object
# age                  5110 non-null float64
# hypertension         5110 non-null int64
# heart_disease        5110 non-null int64
# ever_married         5110 non-null object
# work_type            5110 non-null object
# Residence_type       5110 non-null object
# avg_glucose_level    5110 non-null float64
# bmi                  5110 non-null float64
# smoking_status       5110 non-null object
# stroke               5110 non-null int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
# print positive/negative labels
df['stroke'].value_counts()
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %%
df['gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
df['ever_married'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['work_type'].unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job', 'children', 'Never_worked'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df['gender'] = labelencoder.fit_transform(df['gender'])

labelencoder = LabelEncoder()
df['ever_married'] = labelencoder.fit_transform(df['ever_married'])

labelencoder = LabelEncoder()
df['work_type'] = labelencoder.fit_transform(df['work_type'])

labelencoder = LabelEncoder()
df['Residence_type'] = labelencoder.fit_transform(df['Residence_type'])

labelencoder = LabelEncoder()
df['smoking_status'] = labelencoder.fit_transform(df['smoking_status'])

# %%
df.groupby(['gender'])['age'].transform('mean')
# Out:
# 0       42.483385
# 1       43.757395
# 2       42.483385
# 3       43.757395
# 4       43.757395
#           ...
# 5105    43.757395
# 5106    43.757395
# 5107    43.757395
# 5108    42.483385
# 5109    43.757395
# Name: age, Length: 5110, dtype: float64

# %%
X = df.drop(['stroke', 'id'], axis = 1)
y = df['stroke']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.model_selection import GridSearchCV
import lightgbm as lgb

# %%
model = lgb.LGBMClassifier()
lgb_params = {
    'boosting_type': ['gbdt'],
    'objective': ['binary'],
    'num_leaves': [10, 15, 20],
    'learning_rate': [0.01, 0.06],
    'max_depth': [2, 3, 4],
    'reg_lambda': [0, 1, 3],
    'reg_alpha':[0, 1, 3],
    'is_unbalance':[True],
    'metric':['auc']
}

# %%
grid_cv = GridSearchCV(model, lgb_params, cv = 3, verbose = 10)
grid_cv.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# [CV] boosting_type=gbdt, is_unbalance=True, learning_rate=0.01, max_depth=2, metric=auc, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=0
# [CV]  boosting_type=gbdt, is_unbalance=True, learning_rate=0.01, max_depth=2, metric=auc, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=0, score=0.894, total=   0.0s
# [CV] boosting_type=gbdt, is_unbalance=True, learning_rate=0.01, max_depth=2, metric=auc, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=0
# [CV]  boosting_type=gbdt, is_unbalance=True, learning_rate=0.01, max_depth=2, metric=auc, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=0, score=0.831, total=   0.0s
# [CV] boosting_type=gbdt, is_unbalance=True, learning_rate=0.01, max_depth=2, metric=auc, num_leaves=10, objective=binary, reg_alpha=0, reg_lambda=0
# ...

# %%
print(grid_cv.best_params_)
# Out:
# {'boosting_type': 'gbdt', 'is_unbalance': True, 'learning_rate': 0.01, 'max_depth': 4, 'metric': 'auc', 'num_leaves': 15, 'objective': 'binary', 'reg_alpha': 0, 'reg_lambda': 0}

# %%
# define categorical variables
categorical_features = ['gender', 'ever_married', 'hypertension', 'heart_disease', 'work_type', 'Residence_type', 'smoking_status', 'Risk']
# build the lightgbm model
import lightgbm as lgb
best_params = grid_cv.best_params_
lgb_train = lgb.Dataset(X_train, y_train, categorical_feature = categorical_features)
lgb_test = lgb.Dataset(X_test, y_test, categorical_feature = categorical_features)
bst = lgb.train(best_params, lgb_train, 1000, valid_sets=lgb_test, early_stopping_rounds=20)
# Out:
# [LightGBM] [Info] Number of positive: 173, number of negative: 3404
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000518 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 639
# [LightGBM] [Info] Number of data points in the train set: 3577, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.048365 -> initscore=-2.979415
# [LightGBM] [Info] Start training from score -2.979415
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's auc: 0.801873
# Training until validation scores don't improve for 20 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's auc: 0.804293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's auc: 0.804293
# ...

# %%
plt.figure(figsize=(12,6))
lgb.plot_importance(bst, max_num_features=30)
plt.title("Feature importances")
plt.show()

# %%
y_pred = bst.predict(X_test)
y_pred = np.where(y_pred > 0.5, 1, 0)

y_pred_train = bst.predict(X_train)
y_pred_train = np.where(y_pred_train > 0.5, 1, 0)

# %%
# view accuracy
from sklearn.metrics import accuracy_score
# print the scores on training and test set
print('Training set score: {:.4f}'.format(accuracy_score(y_train, y_pred_train)))
print('Test set score: {:.4f}'.format(accuracy_score(y_test, y_pred)))
# Out:
# Training set score: 0.9516
# Test set score: 0.9504

# %%
import sklearn.metrics as metrics
# calculate the fpr and tpr for all thresholds of the classification
probs = bst.predict(X_test)
fpr, tpr, threshold = metrics.roc_curve(y_test, probs)
roc_auc = metrics.auc(fpr, tpr)

# method I: plt
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([-0.03, 1])
plt.ylim([0, 1.03])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
